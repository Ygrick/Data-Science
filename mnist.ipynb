# %% [markdown]
# <a href="https://colab.research.google.com/github/Ygrick/colab/blob/main/mnist.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  https://habr.com/en/company/wunderfund/blog/314242/
#
#  https://habr.com/en/post/454034/
#
#  https://www.youtube.com/watch?v=GKpVjx_b1Z4
#
#  https://habr.com/en/post/426797/
#
#  https://www.youtube.com/watch?v=8mkh4uGxNfo

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.models import Sequential
from tensorflow import keras
import tensorflow as tf

# %%
# get training and testing vectors 
(trainX, trainy), (testX, testy) = fashion_mnist.load_data()

# %%
#printing the shapes of vectors 
print('X_train: ' + str(trainX.shape))
print('Y_train: ' + str(trainy.shape))
print('X_test:  '  + str(testX.shape))
print('Y_test:  '  + str(testy.shape))
# Out:
# X_train: (60000, 28, 28)
# Y_train: (60000,)
# X_test:  (10000, 28, 28)
# Y_test:  (10000,)

# %%
class_names = ['T-shirt', 'Trouser', 'Pullover', 'Dress', 'Coat', 
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
plt.figure(figsize=(5, 5))
#plotting 
for i in range(9):
  plt.subplot(3, 3, i+1)
  plt.xticks([])
  plt.yticks([])
  plt.imshow(trainX[i], cmap=plt.get_cmap('gray'))
  plt.xlabel(class_names[trainy[i]])

# %%
trainX = trainX / 255.0
testX = testX / 255.0

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(128, activation=tf.nn.relu),
    keras.layers.Dense(10, activation=tf.nn.softmax)
])

# %%
model.compile(optimizer=keras.optimizers.SGD(learning_rate=0.01), 
              loss='sparse_categorical_crossentropy',
              metrics=["accuracy"])

# %%
model.fit(trainX, trainy, epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2432 - accuracy: 0.9138
# Epoch 2/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2417 - accuracy: 0.9140
# Epoch 3/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2397 - accuracy: 0.9146
# Epoch 4/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2381 - accuracy: 0.9151
# Epoch 5/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2364 - accuracy: 0.9161
# Epoch 6/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2348 - accuracy: 0.9169
# Epoch 7/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2326 - accuracy: 0.9174
# Epoch 8/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2310 - accuracy: 0.9181
# Epoch 9/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2296 - accuracy: 0.9191
# Epoch 10/10
# ...

# %%
test_loss, test_acc = model.evaluate(testX, testy)
test_acc
# Out:
# 313/313 [==============================] - 0s 2ms/step - loss: 0.3217 - accuracy: 0.8841
# 0.8841000199317932
